# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Heart Failure")
heart_failure = pd.read_pickle("EditedData/BalancedProtectedAttributes/HeartFailure_Results_Bal_P_Pickle")
display(heart_failure)

print("Diabetes")
diabetes = pd.read_pickle("EditedData/BalancedProtectedAttributes/Diabetes_Results_Bal_P_Pickle")
display(diabetes)

print("PostAcute")
post_acute = pd.read_pickle("EditedData/BalancedProtectedAttributes/PostAcute_Results_Bal_P_Pickle")
display(post_acute)

print("Sepsis")
sepsis = pd.read_pickle("EditedData/BalancedProtectedAttributes/Sepsis_Results_Bal_P_Pickle")
display(sepsis)
# Out:
# Heart Failure
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.550984       0.027255
# Reweighing               Logistic Regression  0.555619       0.111748
# Disparate Impact Remover Logistic Regression  0.552098       0.072832
# Prejudice Remover        Logistic Regression  0.568770       0.030658
# Adversarial Debias       GD(No Debias)        0.574016      -0.038713
#                          GD(Debased)          0.554937       0.104918
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.040426       0.023313
# Reweighing               Logistic Regression  1.220927       0.100298
# Disparate Impact Remover Logistic Regression  1.152030       0.070885
# Prejudice Remover        Logistic Regression  1.078496       0.027450
# Adversarial Debias       GD(No Debias)        0.852158      -0.042629
#                          GD(Debased)          1.386312       0.101911
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.048044   0.219688
# Reweighing               Logistic Regression     0.179273   0.257647
# Disparate Impact Remover Logistic Regression     0.081001   0.261305
# Prejudice Remover        Logistic Regression     0.045464   0.318600
# Adversarial Debias       GD(No Debias)          -0.019853   0.360941
#                          GD(Debased)             0.119516   0.351800
# Diabetes
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.630193       0.014905
# Reweighing               Logistic Regression  0.629830       0.000439
# Disparate Impact Remover Logistic Regression  0.634540       0.038524
# Prejudice Remover        Logistic Regression  0.623010       0.001996
# Adversarial Debias       GD(No Debias)        0.600331      -0.003770
#                          GD(Debased)          0.602758      -0.035204
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.040622       0.021608
# Reweighing               Logistic Regression  1.013294       0.007163
# Disparate Impact Remover Logistic Regression  1.095390       0.045669
# Prejudice Remover        Logistic Regression  1.018297       0.009107
# Adversarial Debias       GD(No Debias)        1.005110       0.002067
#                          GD(Debased)          0.942148      -0.029047
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.026570   0.209229
# Reweighing               Logistic Regression     0.011808   0.209666
# Disparate Impact Remover Logistic Regression     0.048096   0.226633
# Prejudice Remover        Logistic Regression     0.005058   0.233914
# Adversarial Debias       GD(No Debias)          -0.001610   0.298484
#                          GD(Debased)            -0.034556   0.254740
# PostAcute
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.704712      -0.047235
# Reweighing               Logistic Regression  0.702703      -0.006855
# Disparate Impact Remover Logistic Regression  0.701040       0.021237
# Prejudice Remover        Logistic Regression  0.694041      -0.050012
# Adversarial Debias       GD(No Debias)        0.534103       0.001780
#                          GD(Debased)          0.549413       0.007450
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.843201      -0.052434
# Reweighing               Logistic Regression  0.965588      -0.012266
# Disparate Impact Remover Logistic Regression  1.039441       0.013900
# Prejudice Remover        Logistic Regression  0.859871      -0.050986
# Adversarial Debias       GD(No Debias)        0.784513      -0.004188
#                          GD(Debased)          1.116101       0.002326
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.045129   0.076989
# Reweighing               Logistic Regression    -0.004475   0.076694
# Disparate Impact Remover Logistic Regression     0.025871   0.076663
# Prejudice Remover        Logistic Regression    -0.052594   0.078174
# Adversarial Debias       GD(No Debias)           0.008039   0.069873
#                          GD(Debased)             0.012436   0.068120
# Sepsis
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.655938       0.131183
# Reweighing               Logistic Regression  0.730938      -0.041564
# Disparate Impact Remover Logistic Regression  0.683750       0.269022
# Prejudice Remover        Logistic Regression  0.622812      -0.068983
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  2.627838       0.061428
# Reweighing               Logistic Regression  0.878259      -0.022357
# Disparate Impact Remover Logistic Regression  3.872346       0.234846
# Prejudice Remover        Logistic Regression  0.551923      -0.041708
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.200000   0.033297
# Reweighing               Logistic Regression    -0.066667   0.050359
# Disparate Impact Remover Logistic Regression     0.300000   0.056392
# Prejudice Remover        Logistic Regression    -0.100000   0.035619
# Adversarial Debias       GD(No Debias)           0.000000   0.019803
#                          GD(Debased)             0.000000   0.019803

# %%
heart_failure = heart_failure.abs()
display(heart_failure)

diabetes = diabetes.abs()
display(diabetes)

post_acute = post_acute.abs()
display(post_acute)


sepsis = sepsis.abs()
display(sepsis)
# Out:
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.550984       0.027255
# Reweighing               Logistic Regression  0.555619       0.111748
# Disparate Impact Remover Logistic Regression  0.552098       0.072832
# Prejudice Remover        Logistic Regression  0.568770       0.030658
# Adversarial Debias       GD(No Debias)        0.574016       0.038713
#                          GD(Debased)          0.554937       0.104918
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.040426       0.023313
# Reweighing               Logistic Regression  1.220927       0.100298
# Disparate Impact Remover Logistic Regression  1.152030       0.070885
# Prejudice Remover        Logistic Regression  1.078496       0.027450
# Adversarial Debias       GD(No Debias)        0.852158       0.042629
#                          GD(Debased)          1.386312       0.101911
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.048044   0.219688
# Reweighing               Logistic Regression     0.179273   0.257647
# Disparate Impact Remover Logistic Regression     0.081001   0.261305
# Prejudice Remover        Logistic Regression     0.045464   0.318600
# Adversarial Debias       GD(No Debias)           0.019853   0.360941
#                          GD(Debased)             0.119516   0.351800
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.630193       0.014905
# Reweighing               Logistic Regression  0.629830       0.000439
# Disparate Impact Remover Logistic Regression  0.634540       0.038524
# Prejudice Remover        Logistic Regression  0.623010       0.001996
# Adversarial Debias       GD(No Debias)        0.600331       0.003770
#                          GD(Debased)          0.602758       0.035204
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.040622       0.021608
# Reweighing               Logistic Regression  1.013294       0.007163
# Disparate Impact Remover Logistic Regression  1.095390       0.045669
# Prejudice Remover        Logistic Regression  1.018297       0.009107
# Adversarial Debias       GD(No Debias)        1.005110       0.002067
#                          GD(Debased)          0.942148       0.029047
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.026570   0.209229
# Reweighing               Logistic Regression     0.011808   0.209666
# Disparate Impact Remover Logistic Regression     0.048096   0.226633
# Prejudice Remover        Logistic Regression     0.005058   0.233914
# Adversarial Debias       GD(No Debias)           0.001610   0.298484
#                          GD(Debased)             0.034556   0.254740
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.704712       0.047235
# Reweighing               Logistic Regression  0.702703       0.006855
# Disparate Impact Remover Logistic Regression  0.701040       0.021237
# Prejudice Remover        Logistic Regression  0.694041       0.050012
# Adversarial Debias       GD(No Debias)        0.534103       0.001780
#                          GD(Debased)          0.549413       0.007450
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.843201       0.052434
# Reweighing               Logistic Regression  0.965588       0.012266
# Disparate Impact Remover Logistic Regression  1.039441       0.013900
# Prejudice Remover        Logistic Regression  0.859871       0.050986
# Adversarial Debias       GD(No Debias)        0.784513       0.004188
#                          GD(Debased)          1.116101       0.002326
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.045129   0.076989
# Reweighing               Logistic Regression     0.004475   0.076694
# Disparate Impact Remover Logistic Regression     0.025871   0.076663
# Prejudice Remover        Logistic Regression     0.052594   0.078174
# Adversarial Debias       GD(No Debias)           0.008039   0.069873
#                          GD(Debased)             0.012436   0.068120
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.655938       0.131183
# Reweighing               Logistic Regression  0.730938       0.041564
# Disparate Impact Remover Logistic Regression  0.683750       0.269022
# Prejudice Remover        Logistic Regression  0.622812       0.068983
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  2.627838       0.061428
# Reweighing               Logistic Regression  0.878259       0.022357
# Disparate Impact Remover Logistic Regression  3.872346       0.234846
# Prejudice Remover        Logistic Regression  0.551923       0.041708
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.200000   0.033297
# Reweighing               Logistic Regression     0.066667   0.050359
# Disparate Impact Remover Logistic Regression     0.300000   0.056392
# Prejudice Remover        Logistic Regression     0.100000   0.035619
# Adversarial Debias       GD(No Debias)           0.000000   0.019803
#                          GD(Debased)             0.000000   0.019803

# %%
def format_df(df):
    df = df.transpose()
    df.columns = ["None", "Reweighting", "DIR", "PR", "AD(Base)", "AD"]
    return df

heart_failure = format_df(heart_failure)
diabetes = format_df(diabetes)
post_acute = format_df(post_acute)
sepsis = format_df(sepsis)

sepsis
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.655938     0.730938  0.683750  0.622812  0.500000  0.500000
# avg_odds_diff  0.131183     0.041564  0.269022  0.068983  0.000000  0.000000
# disp_imp       2.627838     0.878259  3.872346  0.551923       NaN       NaN
# stat_par_diff  0.061428     0.022357  0.234846  0.041708  0.000000  0.000000
# eq_opp_diff    0.200000     0.066667  0.300000  0.100000  0.000000  0.000000
# theil_ind      0.033297     0.050359  0.056392  0.035619  0.019803  0.019803

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.pairplot(heart_failure)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('No Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('Row Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')

r0 = np.arange(0.56, 0.74, step=0.02)
r1 = np.arange(0, 0.2, step=0.02)
r2 = np.arange(0.6, 1.3, step=0.1)
r3 = np.arange(0, 0.22, step=0.02)
r4 = np.arange(0, 0.22, step=0.02)
r5 = np.arange(0, 0.3, step=0.02)


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')
ax.set_yticks(r0)




df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')
ax.set_yticks(r1)


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')
ax.set_yticks(r3)



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')
ax.set_yticks(r4)


df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('All Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


plt.setp(axs, yticks=(np.arange(0, 1, step=0.2)))
# Out:
# [<matplotlib.axis.YTick at 0x274baf374c0>,
#  <matplotlib.axis.YTick at 0x274baf370a0>,
#  <matplotlib.axis.YTick at 0x274bb35ff10>,
#  <matplotlib.axis.YTick at 0x274bc8233a0>,
#  <matplotlib.axis.YTick at 0x274bc8238b0>,
#  <matplotlib.axis.YTick at 0x274baf62760>,
#  <matplotlib.axis.YTick at 0x274baf62340>,
#  <matplotlib.axis.YTick at 0x274baf5e190>,
#  <matplotlib.axis.YTick at 0x274bc82b3a0>,
#  <matplotlib.axis.YTick at 0x274bc82b8b0>,
#  <matplotlib.axis.YTick at 0x274baf77bb0>,
#  <matplotlib.axis.YTick at 0x274baf77790>,
#  <matplotlib.axis.YTick at 0x274baf745e0>,
#  <matplotlib.axis.YTick at 0x274bc8303a0>,
#  <matplotlib.axis.YTick at 0x274bc8308b0>,
#  <matplotlib.axis.YTick at 0x274baffefd0>,
#  <matplotlib.axis.YTick at 0x274baffebb0>,
#  <matplotlib.axis.YTick at 0x274baffca00>,
#  <matplotlib.axis.YTick at 0x274bc8234f0>,
#  <matplotlib.axis.YTick at 0x274bc830ca0>,
#  <matplotlib.axis.YTick at 0x274bb030430>,
#  <matplotlib.axis.YTick at 0x274bb02cfd0>,
#  <matplotlib.axis.YTick at 0x274bb028e20>,
#  <matplotlib.axis.YTick at 0x274bc837790>,
#  <matplotlib.axis.YTick at 0x274bc837ca0>,
#  <matplotlib.axis.YTick at 0x274bb05e880>,
#  <matplotlib.axis.YTick at 0x274bb05e460>,
#  <matplotlib.axis.YTick at 0x274bb05b2b0>,
#  <matplotlib.axis.YTick at 0x274bc83d790>,
#  <matplotlib.axis.YTick at 0x274bc83dca0>,
#  <matplotlib.axis.YTick at 0x274bb08dca0>,
#  <matplotlib.axis.YTick at 0x274bb08d880>,
#  <matplotlib.axis.YTick at 0x274bb0886d0>,
#  <matplotlib.axis.YTick at 0x274bc8374c0>,
#  <matplotlib.axis.YTick at 0x274bc82b0a0>,
#  <matplotlib.axis.YTick at 0x274bb0c10d0>,
#  <matplotlib.axis.YTick at 0x274bb0bdc70>,
#  <matplotlib.axis.YTick at 0x274bb0b9ac0>,
#  <matplotlib.axis.YTick at 0x274bc844100>,
#  <matplotlib.axis.YTick at 0x274bc844610>,
#  <matplotlib.axis.YTick at 0x274bb0ed610>,
#  <matplotlib.axis.YTick at 0x274bb0ed1f0>,
#  <matplotlib.axis.YTick at 0x274bb0e6940>,
#  <matplotlib.axis.YTick at 0x274bc8460d0>,
#  <matplotlib.axis.YTick at 0x274bc8465e0>,
#  <matplotlib.axis.YTick at 0x274bb119a30>,
#  <matplotlib.axis.YTick at 0x274bb119610>,
#  <matplotlib.axis.YTick at 0x274bb112d60>,
#  <matplotlib.axis.YTick at 0x274bc82bac0>,
#  <matplotlib.axis.YTick at 0x274bc846940>,
#  <matplotlib.axis.YTick at 0x274bb14be50>,
#  <matplotlib.axis.YTick at 0x274bb14ba30>,
#  <matplotlib.axis.YTick at 0x274bb14b1c0>,
#  <matplotlib.axis.YTick at 0x274bc8522b0>,
#  <matplotlib.axis.YTick at 0x274bc8527c0>,
#  <matplotlib.axis.YTick at 0x274bb1812b0>,
#  <matplotlib.axis.YTick at 0x274bb17be50>,
#  <matplotlib.axis.YTick at 0x274bb17b5e0>,
#  <matplotlib.axis.YTick at 0x274bc857280>,
#  <matplotlib.axis.YTick at 0x274bc857790>,
#  <matplotlib.axis.YTick at 0x274bb1af6d0>,
#  <matplotlib.axis.YTick at 0x274bb1af2b0>,
#  <matplotlib.axis.YTick at 0x274bb1a8a00>,
#  <matplotlib.axis.YTick at 0x274bc846250>,
#  <matplotlib.axis.YTick at 0x274bc857b50>,
#  <matplotlib.axis.YTick at 0x274bb1deaf0>,
#  <matplotlib.axis.YTick at 0x274bb1de6d0>,
#  <matplotlib.axis.YTick at 0x274bb1d7e20>,
#  <matplotlib.axis.YTick at 0x274bd830460>,
#  <matplotlib.axis.YTick at 0x274bd830970>,
#  <matplotlib.axis.YTick at 0x274bb20ef10>,
#  <matplotlib.axis.YTick at 0x274bb20eaf0>,
#  <matplotlib.axis.YTick at 0x274bb20e280>,
#  <matplotlib.axis.YTick at 0x274bd835430>,
#  <matplotlib.axis.YTick at 0x274bd835940>,
#  <matplotlib.axis.YTick at 0x274bb248370>,
#  <matplotlib.axis.YTick at 0x274bb23ef10>,
#  <matplotlib.axis.YTick at 0x274bb23e6a0>,
#  <matplotlib.axis.YTick at 0x274bc830dc0>,
#  <matplotlib.axis.YTick at 0x274bd835670>,
#  <matplotlib.axis.YTick at 0x274bb276790>,
#  <matplotlib.axis.YTick at 0x274bb276370>,
#  <matplotlib.axis.YTick at 0x274bb26fac0>,
#  <matplotlib.axis.YTick at 0x274bd83a610>,
#  <matplotlib.axis.YTick at 0x274bd83ab20>,
#  <matplotlib.axis.YTick at 0x274bb2a6bb0>,
#  <matplotlib.axis.YTick at 0x274bb2a6790>,
#  <matplotlib.axis.YTick at 0x274bb29cee0>,
#  <matplotlib.axis.YTick at 0x274bd8405e0>,
#  <matplotlib.axis.YTick at 0x274bd840af0>,
#  <matplotlib.axis.YTick at 0x274bb2d6fd0>,
#  <matplotlib.axis.YTick at 0x274bb2d6bb0>,
#  <matplotlib.axis.YTick at 0x274bb2d6340>,
#  <matplotlib.axis.YTick at 0x274bc852340>,
#  <matplotlib.axis.YTick at 0x274bd840760>,
#  <matplotlib.axis.YTick at 0x274bb30c430>,
#  <matplotlib.axis.YTick at 0x274bb307fd0>,
#  <matplotlib.axis.YTick at 0x274bb307760>,
#  <matplotlib.axis.YTick at 0x274bd8497c0>,
#  <matplotlib.axis.YTick at 0x274bd849cd0>,
#  <matplotlib.axis.YTick at 0x274bb37c850>,
#  <matplotlib.axis.YTick at 0x274bb37c430>,
#  <matplotlib.axis.YTick at 0x274bb375b80>,
#  <matplotlib.axis.YTick at 0x274bd84f790>,
#  <matplotlib.axis.YTick at 0x274bd84fca0>,
#  <matplotlib.axis.YTick at 0x274bbc0ac70>,
#  <matplotlib.axis.YTick at 0x274bbc0a850>,
#  <matplotlib.axis.YTick at 0x274bbc02fa0>,
#  <matplotlib.axis.YTick at 0x274bd8493d0>,
#  <matplotlib.axis.YTick at 0x274bd83a190>,
#  <matplotlib.axis.YTick at 0x274bbc430d0>,
#  <matplotlib.axis.YTick at 0x274bbc3ac70>,
#  <matplotlib.axis.YTick at 0x274bbc3a400>,
#  <matplotlib.axis.YTick at 0x274bd856970>,
#  <matplotlib.axis.YTick at 0x274bd856e80>,
#  <matplotlib.axis.YTick at 0x274bbc714f0>,
#  <matplotlib.axis.YTick at 0x274bbc710d0>,
#  <matplotlib.axis.YTick at 0x274bbc6b820>,
#  <matplotlib.axis.YTick at 0x274bd85a940>,
#  <matplotlib.axis.YTick at 0x274bd85ae50>,
#  <matplotlib.axis.YTick at 0x274bbca3910>,
#  <matplotlib.axis.YTick at 0x274bbca34f0>,
#  <matplotlib.axis.YTick at 0x274bbc99c40>,
#  <matplotlib.axis.YTick at 0x274bd8565e0>,
#  <matplotlib.axis.YTick at 0x274bd849f10>,
#  <matplotlib.axis.YTick at 0x274bbcd2d30>,
#  <matplotlib.axis.YTick at 0x274bbcd2910>,
#  <matplotlib.axis.YTick at 0x274bbcc8e50>,
#  <matplotlib.axis.YTick at 0x274bd863b20>,
#  <matplotlib.axis.YTick at 0x274bd867070>,
#  <matplotlib.axis.YTick at 0x274bbd0a190>,
#  <matplotlib.axis.YTick at 0x274bbd03d30>,
#  <matplotlib.axis.YTick at 0x274bbd034c0>,
#  <matplotlib.axis.YTick at 0x274bd867af0>,
#  <matplotlib.axis.YTick at 0x274bd86c040>,
#  <matplotlib.axis.YTick at 0x274bbd395b0>,
#  <matplotlib.axis.YTick at 0x274bbd39190>,
#  <matplotlib.axis.YTick at 0x274bbd328e0>,
#  <matplotlib.axis.YTick at 0x274bd863790>,
#  <matplotlib.axis.YTick at 0x274bd85a100>]

# %%
plt.rcParams['figure.figsize'] = [12, 5]
display(heart_failure)

#heart_failure.index = heart_failure.index.droplevel(1)
heart_failure.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.550984     0.555619  0.552098  0.568770  0.574016  0.554937
# avg_odds_diff  0.027255     0.111748  0.072832  0.030658  0.038713  0.104918
# disp_imp       1.040426     1.220927  1.152030  1.078496  0.852158  1.386312
# stat_par_diff  0.023313     0.100298  0.070885  0.027450  0.042629  0.101911
# eq_opp_diff    0.048044     0.179273  0.081001  0.045464  0.019853  0.119516
# theil_ind      0.219688     0.257647  0.261305  0.318600  0.360941  0.351800
# <AxesSubplot:>

# %%
display(diabetes)

#diabetes.index = diabetes.index.droplevel(1)

diabetes.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.630193     0.629830  0.634540  0.623010  0.600331  0.602758
# avg_odds_diff  0.014905     0.000439  0.038524  0.001996  0.003770  0.035204
# disp_imp       1.040622     1.013294  1.095390  1.018297  1.005110  0.942148
# stat_par_diff  0.021608     0.007163  0.045669  0.009107  0.002067  0.029047
# eq_opp_diff    0.026570     0.011808  0.048096  0.005058  0.001610  0.034556
# theil_ind      0.209229     0.209666  0.226633  0.233914  0.298484  0.254740
# <AxesSubplot:>

# %%
display(post_acute)

#post_acute.index = post_acute.index.droplevel(1)
post_acute.plot()
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.698149       0.033659  0.838760       0.063569
# Reweighing                0.699344       0.027404  0.987916       0.004322
# Disparate Impact Remover  0.698967       0.015052  0.816648       0.055440
# Prejudice Remover         0.689673       0.044511  1.017126       0.005075
# Adversarial Debias        0.538165       0.005682  0.892892       0.003187
# Adversarial Debias        0.527339       0.006068  1.015030       0.000230
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.005952   0.078847
# Reweighing                   0.057143   0.078707
# Disparate Impact Remover     0.025000   0.079396
# Prejudice Remover            0.083730   0.081172
# Adversarial Debias           0.014683   0.077678
# Adversarial Debias           0.011905   0.076449
# <AxesSubplot:xlabel='Bias Mitigator'>
