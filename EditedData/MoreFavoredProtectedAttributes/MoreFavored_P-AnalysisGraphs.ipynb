# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
target_folder = "MoreFavoredProtectedAttributes"
prefix_folder = "MoreFavored"

# %%
print("Heart Failure")
heart_failure = pd.read_pickle("HeartFailure_Results_"+ prefix_folder+"_P_Pickle")
display(heart_failure)

print("Diabetes")
diabetes = pd.read_pickle("Diabetes_Results_"+ prefix_folder+"_P_Pickle")
display(diabetes)

print("PostAcute")
post_acute = pd.read_pickle("PostAcute_Results_"+ prefix_folder+"_P_Pickle")
display(post_acute)

print("Sepsis")
sepsis = pd.read_pickle("Sepsis_Results_"+ prefix_folder+"_P_Pickle")
display(sepsis)
# Out:
# Heart Failure
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.574289      -0.176307
# Reweighing               Logistic Regression  0.574289      -0.176307
# Disparate Impact Remover Logistic Regression  0.587486      -0.288520
# Prejudice Remover        Logistic Regression  0.543835      -0.184907
# Adversarial Debias       GD(No Debias)        0.577335      -0.149442
#                          GD(Debased)          0.528147       0.583267
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.697040      -0.165953
# Reweighing               Logistic Regression  0.697040      -0.165953
# Disparate Impact Remover Logistic Regression  0.559138      -0.272380
# Prejudice Remover        Logistic Regression  0.734833      -0.170585
# Adversarial Debias       GD(No Debias)        0.519008      -0.134800
#                          GD(Debased)          6.184848       0.594441
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.251515   0.238734
# Reweighing               Logistic Regression    -0.251515   0.238734
# Disparate Impact Remover Logistic Regression    -0.392424   0.211358
# Prejudice Remover        Logistic Regression    -0.262121   0.212236
# Adversarial Debias       GD(No Debias)          -0.243939   0.353931
#                          GD(Debased)             0.518182   0.381937
# Diabetes
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.632309       0.017592
# Reweighing               Logistic Regression  0.633649      -0.012650
# Disparate Impact Remover Logistic Regression  0.637286      -0.001506
# Prejudice Remover        Logistic Regression  0.621816       0.008214
# Adversarial Debias       GD(No Debias)        0.604405      -0.002284
#                          GD(Debased)          0.608137       0.003308
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.038560       0.020002
# Reweighing               Logistic Regression  0.978791      -0.010709
# Disparate Impact Remover Logistic Regression  1.000013       0.000006
# Prejudice Remover        Logistic Regression  1.027772       0.011840
# Adversarial Debias       GD(No Debias)        0.999356      -0.000257
#                          GD(Debased)          1.012240       0.004838
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.024095   0.222053
# Reweighing               Logistic Regression     0.001508   0.231193
# Disparate Impact Remover Logistic Regression     0.020372   0.258453
# Prejudice Remover        Logistic Regression    -0.007278   0.277020
# Adversarial Debias       GD(No Debias)           0.000961   0.304580
#                          GD(Debased)             0.015355   0.303755
# PostAcute
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.668554      -0.059170
# Reweighing               Logistic Regression  0.679168      -0.015773
# Disparate Impact Remover Logistic Regression  0.672605      -0.148161
# Prejudice Remover        Logistic Regression  0.651164      -0.160265
# Adversarial Debias       GD(No Debias)        0.527927      -0.010845
#                          GD(Debased)          0.522221      -0.014729
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.899969      -0.025733
# Reweighing               Logistic Regression  0.960512      -0.015496
# Disparate Impact Remover Logistic Regression  0.580499      -0.120932
# Prejudice Remover        Logistic Regression  0.914069      -0.025049
# Adversarial Debias       GD(No Debias)        1.086771       0.002465
#                          GD(Debased)          0.688475      -0.005146
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.100535   0.083654
# Reweighing               Logistic Regression    -0.018717   0.080030
# Disparate Impact Remover Logistic Regression    -0.182353   0.083321
# Prejudice Remover        Logistic Regression    -0.319786   0.086995
# Adversarial Debias       GD(No Debias)          -0.026738   0.079531
#                          GD(Debased)            -0.026203   0.077022
# Sepsis
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.694241      -0.043788
# Reweighing               Logistic Regression  0.713895      -0.126086
# Disparate Impact Remover Logistic Regression  0.697836       0.029875
# Prejudice Remover        Logistic Regression  0.696039      -0.006956
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.254797       0.061709
# Reweighing               Logistic Regression  0.739928      -0.067558
# Disparate Impact Remover Logistic Regression  1.880349       0.139847
# Prejudice Remover        Logistic Regression  1.502581       0.100778
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.155172   0.059950
# Reweighing               Logistic Regression    -0.189655   0.058572
# Disparate Impact Remover Logistic Regression    -0.086207   0.053014
# Prejudice Remover        Logistic Regression    -0.120690   0.056975
# Adversarial Debias       GD(No Debias)           0.000000   0.017328
#                          GD(Debased)             0.000000   0.017328

# %%
heart_failure = heart_failure.abs()
display(heart_failure)

diabetes = diabetes.abs()
display(diabetes)

post_acute = post_acute.abs()
display(post_acute)


sepsis = sepsis.abs()
display(sepsis)
# Out:
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.574289       0.176307
# Reweighing               Logistic Regression  0.574289       0.176307
# Disparate Impact Remover Logistic Regression  0.587486       0.288520
# Prejudice Remover        Logistic Regression  0.543835       0.184907
# Adversarial Debias       GD(No Debias)        0.577335       0.149442
#                          GD(Debased)          0.528147       0.583267
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.697040       0.165953
# Reweighing               Logistic Regression  0.697040       0.165953
# Disparate Impact Remover Logistic Regression  0.559138       0.272380
# Prejudice Remover        Logistic Regression  0.734833       0.170585
# Adversarial Debias       GD(No Debias)        0.519008       0.134800
#                          GD(Debased)          6.184848       0.594441
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.251515   0.238734
# Reweighing               Logistic Regression     0.251515   0.238734
# Disparate Impact Remover Logistic Regression     0.392424   0.211358
# Prejudice Remover        Logistic Regression     0.262121   0.212236
# Adversarial Debias       GD(No Debias)           0.243939   0.353931
#                          GD(Debased)             0.518182   0.381937
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.632309       0.017592
# Reweighing               Logistic Regression  0.633649       0.012650
# Disparate Impact Remover Logistic Regression  0.637286       0.001506
# Prejudice Remover        Logistic Regression  0.621816       0.008214
# Adversarial Debias       GD(No Debias)        0.604405       0.002284
#                          GD(Debased)          0.608137       0.003308
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.038560       0.020002
# Reweighing               Logistic Regression  0.978791       0.010709
# Disparate Impact Remover Logistic Regression  1.000013       0.000006
# Prejudice Remover        Logistic Regression  1.027772       0.011840
# Adversarial Debias       GD(No Debias)        0.999356       0.000257
#                          GD(Debased)          1.012240       0.004838
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.024095   0.222053
# Reweighing               Logistic Regression     0.001508   0.231193
# Disparate Impact Remover Logistic Regression     0.020372   0.258453
# Prejudice Remover        Logistic Regression     0.007278   0.277020
# Adversarial Debias       GD(No Debias)           0.000961   0.304580
#                          GD(Debased)             0.015355   0.303755
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.668554       0.059170
# Reweighing               Logistic Regression  0.679168       0.015773
# Disparate Impact Remover Logistic Regression  0.672605       0.148161
# Prejudice Remover        Logistic Regression  0.651164       0.160265
# Adversarial Debias       GD(No Debias)        0.527927       0.010845
#                          GD(Debased)          0.522221       0.014729
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.899969       0.025733
# Reweighing               Logistic Regression  0.960512       0.015496
# Disparate Impact Remover Logistic Regression  0.580499       0.120932
# Prejudice Remover        Logistic Regression  0.914069       0.025049
# Adversarial Debias       GD(No Debias)        1.086771       0.002465
#                          GD(Debased)          0.688475       0.005146
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.100535   0.083654
# Reweighing               Logistic Regression     0.018717   0.080030
# Disparate Impact Remover Logistic Regression     0.182353   0.083321
# Prejudice Remover        Logistic Regression     0.319786   0.086995
# Adversarial Debias       GD(No Debias)           0.026738   0.079531
#                          GD(Debased)             0.026203   0.077022
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.694241       0.043788
# Reweighing               Logistic Regression  0.713895       0.126086
# Disparate Impact Remover Logistic Regression  0.697836       0.029875
# Prejudice Remover        Logistic Regression  0.696039       0.006956
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.254797       0.061709
# Reweighing               Logistic Regression  0.739928       0.067558
# Disparate Impact Remover Logistic Regression  1.880349       0.139847
# Prejudice Remover        Logistic Regression  1.502581       0.100778
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.155172   0.059950
# Reweighing               Logistic Regression     0.189655   0.058572
# Disparate Impact Remover Logistic Regression     0.086207   0.053014
# Prejudice Remover        Logistic Regression     0.120690   0.056975
# Adversarial Debias       GD(No Debias)           0.000000   0.017328
#                          GD(Debased)             0.000000   0.017328

# %%
def format_df(df):
    df = df.transpose()
    df.columns = ["None", "Reweighting", "DIR", "PR", "AD(Base)", "AD"]
    return df

heart_failure = format_df(heart_failure)
diabetes = format_df(diabetes)
post_acute = format_df(post_acute)
sepsis = format_df(sepsis)

sepsis
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.694241     0.713895  0.697836  0.696039  0.500000  0.500000
# avg_odds_diff  0.043788     0.126086  0.029875  0.006956  0.000000  0.000000
# disp_imp       1.254797     0.739928  1.880349  1.502581       NaN       NaN
# stat_par_diff  0.061709     0.067558  0.139847  0.100778  0.000000  0.000000
# eq_opp_diff    0.155172     0.189655  0.086207  0.120690  0.000000  0.000000
# theil_ind      0.059950     0.058572  0.053014  0.056975  0.017328  0.017328

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.pairplot(heart_failure)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('No Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('Row Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')

r0 = np.arange(0.56, 0.74, step=0.02)
r1 = np.arange(0, 0.2, step=0.02)
r2 = np.arange(0.6, 1.3, step=0.1)
r3 = np.arange(0, 0.22, step=0.02)
r4 = np.arange(0, 0.22, step=0.02)
r5 = np.arange(0, 0.3, step=0.02)


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')
ax.set_yticks(r0)




df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')
ax.set_yticks(r1)


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')
ax.set_yticks(r3)



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')
ax.set_yticks(r4)


df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post Acute")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('All Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


plt.setp(axs, yticks=(np.arange(0, 1, step=0.2)))
# Out:
# [<matplotlib.axis.YTick at 0x172fb8b7130>,
#  <matplotlib.axis.YTick at 0x172fb8afcd0>,
#  <matplotlib.axis.YTick at 0x172fb8adbe0>,
#  <matplotlib.axis.YTick at 0x172fc2c3e50>,
#  <matplotlib.axis.YTick at 0x172fc2cc3a0>,
#  <matplotlib.axis.YTick at 0x172fb8f9580>,
#  <matplotlib.axis.YTick at 0x172fb8f9160>,
#  <matplotlib.axis.YTick at 0x172fb8f3f70>,
#  <matplotlib.axis.YTick at 0x172fc2cce50>,
#  <matplotlib.axis.YTick at 0x172fc2d33a0>,
#  <matplotlib.axis.YTick at 0x172fb929940>,
#  <matplotlib.axis.YTick at 0x172fb929520>,
#  <matplotlib.axis.YTick at 0x172fb928370>,
#  <matplotlib.axis.YTick at 0x172fc2d3e50>,
#  <matplotlib.axis.YTick at 0x172fc2d35e0>,
#  <matplotlib.axis.YTick at 0x172fb957ca0>,
#  <matplotlib.axis.YTick at 0x172fb957880>,
#  <matplotlib.axis.YTick at 0x172fb9556d0>,
#  <matplotlib.axis.YTick at 0x172fc2d9280>,
#  <matplotlib.axis.YTick at 0x172fc2d9790>,
#  <matplotlib.axis.YTick at 0x172fb98b130>,
#  <matplotlib.axis.YTick at 0x172fb986cd0>,
#  <matplotlib.axis.YTick at 0x172fb983b20>,
#  <matplotlib.axis.YTick at 0x172fc2df280>,
#  <matplotlib.axis.YTick at 0x172fc2df790>,
#  <matplotlib.axis.YTick at 0x172fb9b9580>,
#  <matplotlib.axis.YTick at 0x172fb9b9160>,
#  <matplotlib.axis.YTick at 0x172fb9aef70>,
#  <matplotlib.axis.YTick at 0x172fc2e5280>,
#  <matplotlib.axis.YTick at 0x172fc2df820>,
#  <matplotlib.axis.YTick at 0x172fb9e8880>,
#  <matplotlib.axis.YTick at 0x172fb9e8460>,
#  <matplotlib.axis.YTick at 0x172fb9e32b0>,
#  <matplotlib.axis.YTick at 0x172fc2d30a0>,
#  <matplotlib.axis.YTick at 0x172fc201fa0>,
#  <matplotlib.axis.YTick at 0x172fba17c40>,
#  <matplotlib.axis.YTick at 0x172fba17820>,
#  <matplotlib.axis.YTick at 0x172fba11670>,
#  <matplotlib.axis.YTick at 0x172fc2e5df0>,
#  <matplotlib.axis.YTick at 0x172fc2ee340>,
#  <matplotlib.axis.YTick at 0x172fba48190>,
#  <matplotlib.axis.YTick at 0x172fba41d30>,
#  <matplotlib.axis.YTick at 0x172fba414c0>,
#  <matplotlib.axis.YTick at 0x172fc2eedc0>,
#  <matplotlib.axis.YTick at 0x172fc2ee580>,
#  <matplotlib.axis.YTick at 0x172fba765b0>,
#  <matplotlib.axis.YTick at 0x172fba76190>,
#  <matplotlib.axis.YTick at 0x172fba6e8e0>,
#  <matplotlib.axis.YTick at 0x172fc2df3d0>,
#  <matplotlib.axis.YTick at 0x172fc2f2520>,
#  <matplotlib.axis.YTick at 0x172fbaa59d0>,
#  <matplotlib.axis.YTick at 0x172fbaa55b0>,
#  <matplotlib.axis.YTick at 0x172fba9cd00>,
#  <matplotlib.axis.YTick at 0x172fc2f2fa0>,
#  <matplotlib.axis.YTick at 0x172fc2fa4f0>,
#  <matplotlib.axis.YTick at 0x172fbad5df0>,
#  <matplotlib.axis.YTick at 0x172fbad59d0>,
#  <matplotlib.axis.YTick at 0x172fbad5100>,
#  <matplotlib.axis.YTick at 0x172fc2faf70>,
#  <matplotlib.axis.YTick at 0x172fc2fa730>,
#  <matplotlib.axis.YTick at 0x172fbb0c250>,
#  <matplotlib.axis.YTick at 0x172fbb03df0>,
#  <matplotlib.axis.YTick at 0x172fbb03580>,
#  <matplotlib.axis.YTick at 0x172fc2ee040>,
#  <matplotlib.axis.YTick at 0x172fc3006d0>,
#  <matplotlib.axis.YTick at 0x172fbb3b670>,
#  <matplotlib.axis.YTick at 0x172fbb3b250>,
#  <matplotlib.axis.YTick at 0x172fbb339a0>,
#  <matplotlib.axis.YTick at 0x172fc306190>,
#  <matplotlib.axis.YTick at 0x172fc3066a0>,
#  <matplotlib.axis.YTick at 0x172fbb6aa90>,
#  <matplotlib.axis.YTick at 0x172fbb6a670>,
#  <matplotlib.axis.YTick at 0x172fbb62dc0>,
#  <matplotlib.axis.YTick at 0x172fc30d160>,
#  <matplotlib.axis.YTick at 0x172fc3068e0>,
#  <matplotlib.axis.YTick at 0x172fbb9beb0>,
#  <matplotlib.axis.YTick at 0x172fbb9ba90>,
#  <matplotlib.axis.YTick at 0x172fbb9b220>,
#  <matplotlib.axis.YTick at 0x172fc2fa1c0>,
#  <matplotlib.axis.YTick at 0x172fc30d880>,
#  <matplotlib.axis.YTick at 0x172fbbd1310>,
#  <matplotlib.axis.YTick at 0x172fbbcaeb0>,
#  <matplotlib.axis.YTick at 0x172fbbca640>,
#  <matplotlib.axis.YTick at 0x172fc314340>,
#  <matplotlib.axis.YTick at 0x172fc314850>,
#  <matplotlib.axis.YTick at 0x172fbbff730>,
#  <matplotlib.axis.YTick at 0x172fbbff310>,
#  <matplotlib.axis.YTick at 0x172fbbf8a60>,
#  <matplotlib.axis.YTick at 0x172fc31a310>,
#  <matplotlib.axis.YTick at 0x172fc314970>,
#  <matplotlib.axis.YTick at 0x172fbc2fb50>,
#  <matplotlib.axis.YTick at 0x172fbc2f730>,
#  <matplotlib.axis.YTick at 0x172fbc28e80>,
#  <matplotlib.axis.YTick at 0x172fc3063a0>,
#  <matplotlib.axis.YTick at 0x172fc31aa30>,
#  <matplotlib.axis.YTick at 0x172fbc5ff70>,
#  <matplotlib.axis.YTick at 0x172fbc5fb50>,
#  <matplotlib.axis.YTick at 0x172fbc5f2e0>,
#  <matplotlib.axis.YTick at 0x172fc31f4f0>,
#  <matplotlib.axis.YTick at 0x172fc31fa00>,
#  <matplotlib.axis.YTick at 0x172fbfe63d0>,
#  <matplotlib.axis.YTick at 0x172fbfdff70>,
#  <matplotlib.axis.YTick at 0x172fbfdf700>,
#  <matplotlib.axis.YTick at 0x172fc3274c0>,
#  <matplotlib.axis.YTick at 0x172fc31f700>,
#  <matplotlib.axis.YTick at 0x172fc0167f0>,
#  <matplotlib.axis.YTick at 0x172fc0163d0>,
#  <matplotlib.axis.YTick at 0x172fc00db20>,
#  <matplotlib.axis.YTick at 0x172fc3277c0>,
#  <matplotlib.axis.YTick at 0x172fc327be0>,
#  <matplotlib.axis.YTick at 0x172fc044c10>,
#  <matplotlib.axis.YTick at 0x172fc0447f0>,
#  <matplotlib.axis.YTick at 0x172fc03bf40>,
#  <matplotlib.axis.YTick at 0x172fc32f6a0>,
#  <matplotlib.axis.YTick at 0x172fc32fbb0>,
#  <matplotlib.axis.YTick at 0x172fc074fa0>,
#  <matplotlib.axis.YTick at 0x172fc074c10>,
#  <matplotlib.axis.YTick at 0x172fc0743a0>,
#  <matplotlib.axis.YTick at 0x172fd302670>,
#  <matplotlib.axis.YTick at 0x172fc32f8e0>,
#  <matplotlib.axis.YTick at 0x172fc0ae490>,
#  <matplotlib.axis.YTick at 0x172fc0a7fa0>,
#  <matplotlib.axis.YTick at 0x172fc0a77c0>,
#  <matplotlib.axis.YTick at 0x172fd302a30>,
#  <matplotlib.axis.YTick at 0x172fd302d90>,
#  <matplotlib.axis.YTick at 0x172fc0dc8b0>,
#  <matplotlib.axis.YTick at 0x172fc0dc490>,
#  <matplotlib.axis.YTick at 0x172fc0d3be0>,
#  <matplotlib.axis.YTick at 0x172fd30a850>,
#  <matplotlib.axis.YTick at 0x172fd30ad60>,
#  <matplotlib.axis.YTick at 0x172fc10acd0>,
#  <matplotlib.axis.YTick at 0x172fc10a8b0>,
#  <matplotlib.axis.YTick at 0x172fc0fffd0>,
#  <matplotlib.axis.YTick at 0x172fd310820>,
#  <matplotlib.axis.YTick at 0x172fd30aa90>,
#  <matplotlib.axis.YTick at 0x172fc144130>,
#  <matplotlib.axis.YTick at 0x172fc13acd0>,
#  <matplotlib.axis.YTick at 0x172fc13a460>,
#  <matplotlib.axis.YTick at 0x172fd310be0>,
#  <matplotlib.axis.YTick at 0x172fd310f40>]

# %%
plt.rcParams['figure.figsize'] = [12, 5]
display(heart_failure)

#heart_failure.index = heart_failure.index.droplevel(1)
heart_failure.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.574289     0.574289  0.587486  0.543835  0.577335  0.528147
# avg_odds_diff  0.176307     0.176307  0.288520  0.184907  0.149442  0.583267
# disp_imp       0.697040     0.697040  0.559138  0.734833  0.519008  6.184848
# stat_par_diff  0.165953     0.165953  0.272380  0.170585  0.134800  0.594441
# eq_opp_diff    0.251515     0.251515  0.392424  0.262121  0.243939  0.518182
# theil_ind      0.238734     0.238734  0.211358  0.212236  0.353931  0.381937
# <AxesSubplot:>

# %%
display(diabetes)

#diabetes.index = diabetes.index.droplevel(1)

diabetes.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.632309     0.633649  0.637286  0.621816  0.604405  0.608137
# avg_odds_diff  0.017592     0.012650  0.001506  0.008214  0.002284  0.003308
# disp_imp       1.038560     0.978791  1.000013  1.027772  0.999356  1.012240
# stat_par_diff  0.020002     0.010709  0.000006  0.011840  0.000257  0.004838
# eq_opp_diff    0.024095     0.001508  0.020372  0.007278  0.000961  0.015355
# theil_ind      0.222053     0.231193  0.258453  0.277020  0.304580  0.303755
# <AxesSubplot:>

# %%
display(post_acute)

#post_acute.index = post_acute.index.droplevel(1)
post_acute.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.694241     0.713895  0.697836  0.696039  0.500000  0.500000
# avg_odds_diff -0.043788    -0.126086  0.029875 -0.006956  0.000000  0.000000
# disp_imp       1.254797     0.739928  1.880349  1.502581       NaN       NaN
# stat_par_diff  0.061709    -0.067558  0.139847  0.100778  0.000000  0.000000
# eq_opp_diff   -0.155172    -0.189655 -0.086207 -0.120690  0.000000  0.000000
# theil_ind      0.059950     0.058572  0.053014  0.056975  0.017328  0.017328
# <AxesSubplot:>
