# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Heart Failure")
heart_failure = pd.read_pickle("HeartFailure_Results_Pickle")
display(heart_failure)

print("Diabetes")
diabetes = pd.read_pickle("Diabetes_Results_Pickle")
display(diabetes)

print("PostAcute")
post_acute = pd.read_pickle("PostAcute_Results_Pickle")
display(post_acute)

print("Sepsis")
sepsis = pd.read_pickle("Sepsis_Results_Pickle")
display(sepsis)
# Out:
# Heart Failure
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.582911      -0.084798
# Reweighing               Logistic Regression  0.588429      -0.031474
# Disparate Impact Remover Logistic Regression  0.595697      -0.167005
# Prejudice Remover        Logistic Regression  0.573653       0.026369
# Adversarial Debias       GD(No Debias)        0.560098      -0.057676
#                          GD(Debased)          0.561663      -0.081967
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.793933      -0.090230
# Reweighing               Logistic Regression  0.916726      -0.035478
# Disparate Impact Remover Logistic Regression  0.702656      -0.168906
# Prejudice Remover        Logistic Regression  1.042650       0.028265
# Adversarial Debias       GD(No Debias)        0.809662      -0.048429
#                          GD(Debased)          0.739828      -0.076974
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.072426   0.263803
# Reweighing               Logistic Regression    -0.025368   0.252357
# Disparate Impact Remover Logistic Regression    -0.169853   0.221920
# Prejudice Remover        Logistic Regression     0.010846   0.147566
# Adversarial Debias       GD(No Debias)          -0.100551   0.341187
#                          GD(Debased)            -0.108272   0.330792
# Diabetes
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.628369       0.046355
# Reweighing               Logistic Regression  0.627451       0.003013
# Disparate Impact Remover Logistic Regression  0.630303       0.066734
# Prejudice Remover        Logistic Regression  0.620790       0.012530
# Adversarial Debias       GD(No Debias)        0.589824       0.046431
#                          GD(Debased)          0.589710       0.079947
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.105726       0.048438
# Reweighing               Logistic Regression  1.011226       0.005184
# Disparate Impact Remover Logistic Regression  1.146401       0.068909
# Prejudice Remover        Logistic Regression  1.031031       0.014418
# Adversarial Debias       GD(No Debias)        1.126117       0.047605
#                          GD(Debased)          1.177796       0.080658
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.054793   0.244435
# Reweighing               Logistic Regression     0.010134   0.254859
# Disparate Impact Remover Logistic Regression     0.074495   0.231288
# Prejudice Remover        Logistic Regression     0.021412   0.255469
# Adversarial Debias       GD(No Debias)           0.055878   0.313900
#                          GD(Debased)             0.095170   0.263770
# PostAcute
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.698149      -0.033659
# Reweighing               Logistic Regression  0.699344       0.027404
# Disparate Impact Remover Logistic Regression  0.698967      -0.015052
# Prejudice Remover        Logistic Regression  0.689673       0.044511
# Adversarial Debias       GD(No Debias)        0.538165       0.005682
#                          GD(Debased)          0.527339       0.006068
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.838760      -0.063569
# Reweighing               Logistic Regression  0.987916      -0.004322
# Disparate Impact Remover Logistic Regression  0.816648      -0.055440
# Prejudice Remover        Logistic Regression  1.017126       0.005075
# Adversarial Debias       GD(No Debias)        0.892892      -0.003187
#                          GD(Debased)          1.015030       0.000230
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.005952   0.078847
# Reweighing               Logistic Regression     0.057143   0.078707
# Disparate Impact Remover Logistic Regression     0.025000   0.079396
# Prejudice Remover        Logistic Regression     0.083730   0.081172
# Adversarial Debias       GD(No Debias)           0.014683   0.077678
#                          GD(Debased)             0.011905   0.076449
# Sepsis
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.658463      -0.097881
# Reweighing               Logistic Regression  0.671091      -0.048847
# Disparate Impact Remover Logistic Regression  0.676304      -0.069190
# Prejudice Remover        Logistic Regression  0.615819      -0.055268
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.817709      -0.048692
# Reweighing               Logistic Regression  0.934702      -0.016661
# Disparate Impact Remover Logistic Regression  0.857918      -0.046731
# Prejudice Remover        Logistic Regression  1.099961       0.025106
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.148718   0.061042
# Reweighing               Logistic Regression    -0.082051   0.060523
# Disparate Impact Remover Logistic Regression    -0.092308   0.063640
# Prejudice Remover        Logistic Regression    -0.138462   0.063424
# Adversarial Debias       GD(No Debias)           0.000000   0.017586
#                          GD(Debased)             0.000000   0.017586

# %%
heart_failure = heart_failure.abs()
display(heart_failure)

diabetes = diabetes.abs()
display(diabetes)

post_acute = post_acute.abs()
display(post_acute)


sepsis = sepsis.abs()
display(sepsis)
# Out:
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.582911       0.084798
# Reweighing               Logistic Regression  0.588429       0.031474
# Disparate Impact Remover Logistic Regression  0.595697       0.167005
# Prejudice Remover        Logistic Regression  0.573653       0.026369
# Adversarial Debias       GD(No Debias)        0.560098       0.057676
#                          GD(Debased)          0.561663       0.081967
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.793933       0.090230
# Reweighing               Logistic Regression  0.916726       0.035478
# Disparate Impact Remover Logistic Regression  0.702656       0.168906
# Prejudice Remover        Logistic Regression  1.042650       0.028265
# Adversarial Debias       GD(No Debias)        0.809662       0.048429
#                          GD(Debased)          0.739828       0.076974
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.072426   0.263803
# Reweighing               Logistic Regression     0.025368   0.252357
# Disparate Impact Remover Logistic Regression     0.169853   0.221920
# Prejudice Remover        Logistic Regression     0.010846   0.147566
# Adversarial Debias       GD(No Debias)           0.100551   0.341187
#                          GD(Debased)             0.108272   0.330792
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.628369       0.046355
# Reweighing               Logistic Regression  0.627451       0.003013
# Disparate Impact Remover Logistic Regression  0.630303       0.066734
# Prejudice Remover        Logistic Regression  0.620790       0.012530
# Adversarial Debias       GD(No Debias)        0.589824       0.046431
#                          GD(Debased)          0.589710       0.079947
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.105726       0.048438
# Reweighing               Logistic Regression  1.011226       0.005184
# Disparate Impact Remover Logistic Regression  1.146401       0.068909
# Prejudice Remover        Logistic Regression  1.031031       0.014418
# Adversarial Debias       GD(No Debias)        1.126117       0.047605
#                          GD(Debased)          1.177796       0.080658
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.054793   0.244435
# Reweighing               Logistic Regression     0.010134   0.254859
# Disparate Impact Remover Logistic Regression     0.074495   0.231288
# Prejudice Remover        Logistic Regression     0.021412   0.255469
# Adversarial Debias       GD(No Debias)           0.055878   0.313900
#                          GD(Debased)             0.095170   0.263770
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.698149       0.033659
# Reweighing               Logistic Regression  0.699344       0.027404
# Disparate Impact Remover Logistic Regression  0.698967       0.015052
# Prejudice Remover        Logistic Regression  0.689673       0.044511
# Adversarial Debias       GD(No Debias)        0.538165       0.005682
#                          GD(Debased)          0.527339       0.006068
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.838760       0.063569
# Reweighing               Logistic Regression  0.987916       0.004322
# Disparate Impact Remover Logistic Regression  0.816648       0.055440
# Prejudice Remover        Logistic Regression  1.017126       0.005075
# Adversarial Debias       GD(No Debias)        0.892892       0.003187
#                          GD(Debased)          1.015030       0.000230
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.005952   0.078847
# Reweighing               Logistic Regression     0.057143   0.078707
# Disparate Impact Remover Logistic Regression     0.025000   0.079396
# Prejudice Remover        Logistic Regression     0.083730   0.081172
# Adversarial Debias       GD(No Debias)           0.014683   0.077678
#                          GD(Debased)             0.011905   0.076449
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.658463       0.097881
# Reweighing               Logistic Regression  0.671091       0.048847
# Disparate Impact Remover Logistic Regression  0.676304       0.069190
# Prejudice Remover        Logistic Regression  0.615819       0.055268
# Adversarial Debias       GD(No Debias)        0.500000       0.000000
#                          GD(Debased)          0.500000       0.000000
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.817709       0.048692
# Reweighing               Logistic Regression  0.934702       0.016661
# Disparate Impact Remover Logistic Regression  0.857918       0.046731
# Prejudice Remover        Logistic Regression  1.099961       0.025106
# Adversarial Debias       GD(No Debias)             NaN       0.000000
#                          GD(Debased)               NaN       0.000000
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.148718   0.061042
# Reweighing               Logistic Regression     0.082051   0.060523
# Disparate Impact Remover Logistic Regression     0.092308   0.063640
# Prejudice Remover        Logistic Regression     0.138462   0.063424
# Adversarial Debias       GD(No Debias)           0.000000   0.017586
#                          GD(Debased)             0.000000   0.017586

# %%
def format_df(df):
    df = df.transpose()
    df.columns = ["None", "Reweighting", "DIR", "PR", "AD(Base)", "AD"]
    return df

heart_failure = format_df(heart_failure)
diabetes = format_df(diabetes)
post_acute = format_df(post_acute)
sepsis = format_df(sepsis)

sepsis
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.658463     0.671091  0.676304  0.615819  0.500000  0.500000
# avg_odds_diff  0.097881     0.048847  0.069190  0.055268  0.000000  0.000000
# disp_imp       0.817709     0.934702  0.857918  1.099961       NaN       NaN
# stat_par_diff  0.048692     0.016661  0.046731  0.025106  0.000000  0.000000
# eq_opp_diff    0.148718     0.082051  0.092308  0.138462  0.000000  0.000000
# theil_ind      0.061042     0.060523  0.063640  0.063424  0.017586  0.017586

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.pairplot(heart_failure)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('No Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('Row Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')

r0 = np.arange(0.56, 0.74, step=0.02)
r1 = np.arange(0, 0.2, step=0.02)
r2 = np.arange(0.6, 1.3, step=0.1)
r3 = np.arange(0, 0.22, step=0.02)
r4 = np.arange(0, 0.22, step=0.02)
r5 = np.arange(0, 0.3, step=0.02)


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')
ax.set_yticks(r0)




df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')
ax.set_yticks(r1)


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')
ax.set_yticks(r3)



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')
ax.set_yticks(r4)


df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,4)
fig.suptitle('All Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

#Fourth Column


df_c1 = sepsis
col = 3

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Sepsis")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


plt.setp(axs, yticks=(np.arange(0, 1, step=0.2)))
# Out:
# [<matplotlib.axis.YTick at 0x1b9c85e4460>,
#  <matplotlib.axis.YTick at 0x1b9c85ddfd0>,
#  <matplotlib.axis.YTick at 0x1b9c8a4df10>,
#  <matplotlib.axis.YTick at 0x1b9c7c872b0>,
#  <matplotlib.axis.YTick at 0x1b9c7c876d0>,
#  <matplotlib.axis.YTick at 0x1b9c86148e0>,
#  <matplotlib.axis.YTick at 0x1b9c8614490>,
#  <matplotlib.axis.YTick at 0x1b9c860f340>,
#  <matplotlib.axis.YTick at 0x1b9c7d38220>,
#  <matplotlib.axis.YTick at 0x1b9c7c87af0>,
#  <matplotlib.axis.YTick at 0x1b9c862ccd0>,
#  <matplotlib.axis.YTick at 0x1b9c862c8e0>,
#  <matplotlib.axis.YTick at 0x1b9c8623700>,
#  <matplotlib.axis.YTick at 0x1b9c7837bb0>,
#  <matplotlib.axis.YTick at 0x1b9c78373a0>,
#  <matplotlib.axis.YTick at 0x1b9c86b60a0>,
#  <matplotlib.axis.YTick at 0x1b9c86adc40>,
#  <matplotlib.axis.YTick at 0x1b9c86ad3d0>,
#  <matplotlib.axis.YTick at 0x1b9c7caaa30>,
#  <matplotlib.axis.YTick at 0x1b9c7caa040>,
#  <matplotlib.axis.YTick at 0x1b9c86e24c0>,
#  <matplotlib.axis.YTick at 0x1b9c86e20a0>,
#  <matplotlib.axis.YTick at 0x1b9c86d87f0>,
#  <matplotlib.axis.YTick at 0x1b9c5517fd0>,
#  <matplotlib.axis.YTick at 0x1b9c7caabb0>,
#  <matplotlib.axis.YTick at 0x1b9c870e910>,
#  <matplotlib.axis.YTick at 0x1b9c870e4f0>,
#  <matplotlib.axis.YTick at 0x1b9c8707c40>,
#  <matplotlib.axis.YTick at 0x1b9c5517220>,
#  <matplotlib.axis.YTick at 0x1b9c5517130>,
#  <matplotlib.axis.YTick at 0x1b9c873ad30>,
#  <matplotlib.axis.YTick at 0x1b9c873a910>,
#  <matplotlib.axis.YTick at 0x1b9c8730e50>,
#  <matplotlib.axis.YTick at 0x1b9c54ea670>,
#  <matplotlib.axis.YTick at 0x1b9c54ea2b0>,
#  <matplotlib.axis.YTick at 0x1b9c876f160>,
#  <matplotlib.axis.YTick at 0x1b9c8767d00>,
#  <matplotlib.axis.YTick at 0x1b9c8767490>,
#  <matplotlib.axis.YTick at 0x1b9c6e1b610>,
#  <matplotlib.axis.YTick at 0x1b9c54ea100>,
#  <matplotlib.axis.YTick at 0x1b9c876a580>,
#  <matplotlib.axis.YTick at 0x1b9c876a160>,
#  <matplotlib.axis.YTick at 0x1b9c87948b0>,
#  <matplotlib.axis.YTick at 0x1b9c7caa8e0>,
#  <matplotlib.axis.YTick at 0x1b9c557b910>,
#  <matplotlib.axis.YTick at 0x1b9c87c99a0>,
#  <matplotlib.axis.YTick at 0x1b9c87c9580>,
#  <matplotlib.axis.YTick at 0x1b9c87becd0>,
#  <matplotlib.axis.YTick at 0x1b9c6e1bb50>,
#  <matplotlib.axis.YTick at 0x1b9c4adc6d0>,
#  <matplotlib.axis.YTick at 0x1b9c87f6dc0>,
#  <matplotlib.axis.YTick at 0x1b9c87f69a0>,
#  <matplotlib.axis.YTick at 0x1b9c87f60d0>,
#  <matplotlib.axis.YTick at 0x1b9c7c77040>,
#  <matplotlib.axis.YTick at 0x1b9c4adcd30>,
#  <matplotlib.axis.YTick at 0x1b9c882f220>,
#  <matplotlib.axis.YTick at 0x1b9c8825dc0>,
#  <matplotlib.axis.YTick at 0x1b9c8825550>,
#  <matplotlib.axis.YTick at 0x1b9c54ea6d0>,
#  <matplotlib.axis.YTick at 0x1b9c5413820>,
#  <matplotlib.axis.YTick at 0x1b9c885d640>,
#  <matplotlib.axis.YTick at 0x1b9c885d220>,
#  <matplotlib.axis.YTick at 0x1b9c8856970>,
#  <matplotlib.axis.YTick at 0x1b9c5413370>,
#  <matplotlib.axis.YTick at 0x1b9c556ffa0>,
#  <matplotlib.axis.YTick at 0x1b9c888da60>,
#  <matplotlib.axis.YTick at 0x1b9c888d640>,
#  <matplotlib.axis.YTick at 0x1b9c8884d90>,
#  <matplotlib.axis.YTick at 0x1b9c556fcd0>,
#  <matplotlib.axis.YTick at 0x1b9c556f790>,
#  <matplotlib.axis.YTick at 0x1b9c88bde80>,
#  <matplotlib.axis.YTick at 0x1b9c88bda60>,
#  <matplotlib.axis.YTick at 0x1b9c88bd1f0>,
#  <matplotlib.axis.YTick at 0x1b9c4adc670>,
#  <matplotlib.axis.YTick at 0x1b9c7cf3220>,
#  <matplotlib.axis.YTick at 0x1b9c88f52e0>,
#  <matplotlib.axis.YTick at 0x1b9c88ece80>,
#  <matplotlib.axis.YTick at 0x1b9c88ec610>,
#  <matplotlib.axis.YTick at 0x1b9c7c8da30>,
#  <matplotlib.axis.YTick at 0x1b9c7c8d790>,
#  <matplotlib.axis.YTick at 0x1b9c8923700>,
#  <matplotlib.axis.YTick at 0x1b9c89232e0>,
#  <matplotlib.axis.YTick at 0x1b9c891ca30>,
#  <matplotlib.axis.YTick at 0x1b9c7cbff10>,
#  <matplotlib.axis.YTick at 0x1b9c7c8d1c0>,
#  <matplotlib.axis.YTick at 0x1b9c8951b20>,
#  <matplotlib.axis.YTick at 0x1b9c8951700>,
#  <matplotlib.axis.YTick at 0x1b9c894ae50>,
#  <matplotlib.axis.YTick at 0x1b9c7cbf880>,
#  <matplotlib.axis.YTick at 0x1b9c782fd00>,
#  <matplotlib.axis.YTick at 0x1b9c8981f40>,
#  <matplotlib.axis.YTick at 0x1b9c8981b20>,
#  <matplotlib.axis.YTick at 0x1b9c89812b0>,
#  <matplotlib.axis.YTick at 0x1b9c782f3a0>,
#  <matplotlib.axis.YTick at 0x1b9c49f2e20>,
#  <matplotlib.axis.YTick at 0x1b9c89bb3a0>,
#  <matplotlib.axis.YTick at 0x1b9c89b2f40>,
#  <matplotlib.axis.YTick at 0x1b9c89b26d0>,
#  <matplotlib.axis.YTick at 0x1b9c53f5fa0>,
#  <matplotlib.axis.YTick at 0x1b9c4b22550>,
#  <matplotlib.axis.YTick at 0x1b9c9d497c0>,
#  <matplotlib.axis.YTick at 0x1b9c9d493a0>,
#  <matplotlib.axis.YTick at 0x1b9c9d41af0>,
#  <matplotlib.axis.YTick at 0x1b9c7c8dd90>,
#  <matplotlib.axis.YTick at 0x1b9c548b730>,
#  <matplotlib.axis.YTick at 0x1b9c78d9520>,
#  <matplotlib.axis.YTick at 0x1b9c9d787c0>,
#  <matplotlib.axis.YTick at 0x1b9c9d6ef10>,
#  <matplotlib.axis.YTick at 0x1b9c548bb20>,
#  <matplotlib.axis.YTick at 0x1b9c7ccf430>,
#  <matplotlib.axis.YTick at 0x1b9c84e4e80>,
#  <matplotlib.axis.YTick at 0x1b9c8a1bd00>,
#  <matplotlib.axis.YTick at 0x1b9c85cfc70>,
#  <matplotlib.axis.YTick at 0x1b9c7829af0>,
#  <matplotlib.axis.YTick at 0x1b9c7ccf940>,
#  <matplotlib.axis.YTick at 0x1b9c8531880>,
#  <matplotlib.axis.YTick at 0x1b9c8a17a90>,
#  <matplotlib.axis.YTick at 0x1b9c85bceb0>,
#  <matplotlib.axis.YTick at 0x1b9c4b223a0>,
#  <matplotlib.axis.YTick at 0x1b9c78294c0>,
#  <matplotlib.axis.YTick at 0x1b9c85377f0>,
#  <matplotlib.axis.YTick at 0x1b9c853e100>,
#  <matplotlib.axis.YTick at 0x1b9c8a217f0>,
#  <matplotlib.axis.YTick at 0x1b9c77ef6a0>,
#  <matplotlib.axis.YTick at 0x1b9c4c591c0>,
#  <matplotlib.axis.YTick at 0x1b9c7d51b50>,
#  <matplotlib.axis.YTick at 0x1b9c7d52310>,
#  <matplotlib.axis.YTick at 0x1b9c8623040>,
#  <matplotlib.axis.YTick at 0x1b9c53edd90>,
#  <matplotlib.axis.YTick at 0x1b9c53b9340>,
#  <matplotlib.axis.YTick at 0x1b9c77337f0>,
#  <matplotlib.axis.YTick at 0x1b9c7733940>,
#  <matplotlib.axis.YTick at 0x1b9c754cac0>,
#  <matplotlib.axis.YTick at 0x1b9c7ccfee0>,
#  <matplotlib.axis.YTick at 0x1b9c54c0e20>,
#  <matplotlib.axis.YTick at 0x1b9c539e3d0>,
#  <matplotlib.axis.YTick at 0x1b9c77b82b0>,
#  <matplotlib.axis.YTick at 0x1b9c7d5b760>,
#  <matplotlib.axis.YTick at 0x1b9c54c0100>,
#  <matplotlib.axis.YTick at 0x1b9c7d01c40>]

# %%
plt.rcParams['figure.figsize'] = [12, 5]
display(heart_failure)

#heart_failure.index = heart_failure.index.droplevel(1)
heart_failure.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.582911     0.588429  0.595697  0.573653  0.560098  0.561663
# avg_odds_diff  0.084798     0.031474  0.167005  0.026369  0.057676  0.081967
# disp_imp       0.793933     0.916726  0.702656  1.042650  0.809662  0.739828
# stat_par_diff  0.090230     0.035478  0.168906  0.028265  0.048429  0.076974
# eq_opp_diff    0.072426     0.025368  0.169853  0.010846  0.100551  0.108272
# theil_ind      0.263803     0.252357  0.221920  0.147566  0.341187  0.330792
# <AxesSubplot:>

# %%
display(diabetes)

#diabetes.index = diabetes.index.droplevel(1)

diabetes.plot()
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.628369       0.046355  1.105726       0.048438
# Reweighing                0.627451       0.003013  1.011226       0.005184
# Disparate Impact Remover  0.630303       0.066734  1.146401       0.068909
# Prejudice Remover         0.620790       0.012530  1.031031       0.014418
# Adversarial Debias        0.589824       0.046431  1.126117       0.047605
# Adversarial Debias        0.589710       0.079947  1.177796       0.080658
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.054793   0.244435
# Reweighing                   0.010134   0.254859
# Disparate Impact Remover     0.074495   0.231288
# Prejudice Remover            0.021412   0.255469
# Adversarial Debias           0.055878   0.313900
# Adversarial Debias           0.095170   0.263770
# <AxesSubplot:xlabel='Bias Mitigator'>

# %%
display(post_acute)

#post_acute.index = post_acute.index.droplevel(1)
post_acute.plot()
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.698149       0.033659  0.838760       0.063569
# Reweighing                0.699344       0.027404  0.987916       0.004322
# Disparate Impact Remover  0.698967       0.015052  0.816648       0.055440
# Prejudice Remover         0.689673       0.044511  1.017126       0.005075
# Adversarial Debias        0.538165       0.005682  0.892892       0.003187
# Adversarial Debias        0.527339       0.006068  1.015030       0.000230
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.005952   0.078847
# Reweighing                   0.057143   0.078707
# Disparate Impact Remover     0.025000   0.079396
# Prejudice Remover            0.083730   0.081172
# Adversarial Debias           0.014683   0.077678
# Adversarial Debias           0.011905   0.076449
# <AxesSubplot:xlabel='Bias Mitigator'>
