# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Heart Failure")
heart_failure = pd.read_pickle("HeartFailure_Results_Pickle")
display(heart_failure)

print("Diabetes")
diabetes = pd.read_pickle("Diabetes_Results_Pickle")
display(diabetes)

print("PostAcute")
post_acute = pd.read_pickle("PostAcute_Results_Pickle")
display(post_acute)
# Out:
# Heart Failure
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.582911      -0.084798
# Reweighing               Logistic Regression  0.588429      -0.031474
# Disparate Impact Remover Logistic Regression  0.595697      -0.167005
# Prejudice Remover        Logistic Regression  0.573653       0.026369
# Adversarial Debias       GD(No Debias)        0.560098      -0.057676
#                          GD(Debased)          0.561663      -0.081967
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.793933      -0.090230
# Reweighing               Logistic Regression  0.916726      -0.035478
# Disparate Impact Remover Logistic Regression  0.702656      -0.168906
# Prejudice Remover        Logistic Regression  1.042650       0.028265
# Adversarial Debias       GD(No Debias)        0.809662      -0.048429
#                          GD(Debased)          0.739828      -0.076974
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.072426   0.263803
# Reweighing               Logistic Regression    -0.025368   0.252357
# Disparate Impact Remover Logistic Regression    -0.169853   0.221920
# Prejudice Remover        Logistic Regression     0.010846   0.147566
# Adversarial Debias       GD(No Debias)          -0.100551   0.341187
#                          GD(Debased)            -0.108272   0.330792
# Diabetes
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.628369       0.046355
# Reweighing               Logistic Regression  0.627451       0.003013
# Disparate Impact Remover Logistic Regression  0.630303       0.066734
# Prejudice Remover        Logistic Regression  0.620790       0.012530
# Adversarial Debias       GD(No Debias)        0.589824       0.046431
#                          GD(Debased)          0.589710       0.079947
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  1.105726       0.048438
# Reweighing               Logistic Regression  1.011226       0.005184
# Disparate Impact Remover Logistic Regression  1.146401       0.068909
# Prejudice Remover        Logistic Regression  1.031031       0.014418
# Adversarial Debias       GD(No Debias)        1.126117       0.047605
#                          GD(Debased)          1.177796       0.080658
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression     0.054793   0.244435
# Reweighing               Logistic Regression     0.010134   0.254859
# Disparate Impact Remover Logistic Regression     0.074495   0.231288
# Prejudice Remover        Logistic Regression     0.021412   0.255469
# Adversarial Debias       GD(No Debias)           0.055878   0.313900
#                          GD(Debased)             0.095170   0.263770
# PostAcute
#                                                bal_acc  avg_odds_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.698149      -0.033659
# Reweighing               Logistic Regression  0.699344       0.027404
# Disparate Impact Remover Logistic Regression  0.698967      -0.015052
# Prejudice Remover        Logistic Regression  0.689673       0.044511
# Adversarial Debias       GD(No Debias)        0.538165       0.005682
#                          GD(Debased)          0.527339       0.006068
#
#                                               disp_imp  stat_par_diff  \
# Bias Mitigator           Classifier
# None                     Logistic Regression  0.838760      -0.063569
# Reweighing               Logistic Regression  0.987916      -0.004322
# Disparate Impact Remover Logistic Regression  0.816648      -0.055440
# Prejudice Remover        Logistic Regression  1.017126       0.005075
# Adversarial Debias       GD(No Debias)        0.892892      -0.003187
#                          GD(Debased)          1.015030       0.000230
#
#                                               eq_opp_diff  theil_ind
# Bias Mitigator           Classifier
# None                     Logistic Regression    -0.005952   0.078847
# Reweighing               Logistic Regression     0.057143   0.078707
# Disparate Impact Remover Logistic Regression     0.025000   0.079396
# Prejudice Remover        Logistic Regression     0.083730   0.081172
# Adversarial Debias       GD(No Debias)           0.014683   0.077678
#                          GD(Debased)             0.011905   0.076449

# %%
heart_failure = heart_failure.abs()
display(heart_failure)

diabetes = diabetes.abs()
display(diabetes)

post_acute = post_acute.abs()
display(post_acute)
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.582911       0.084798  0.793933       0.090230
# Reweighing                0.588429       0.031474  0.916726       0.035478
# Disparate Impact Remover  0.595697       0.167005  0.702656       0.168906
# Prejudice Remover         0.573653       0.026369  1.042650       0.028265
# Adversarial Debias        0.560098       0.057676  0.809662       0.048429
# Adversarial Debias        0.561663       0.081967  0.739828       0.076974
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.072426   0.263803
# Reweighing                   0.025368   0.252357
# Disparate Impact Remover     0.169853   0.221920
# Prejudice Remover            0.010846   0.147566
# Adversarial Debias           0.100551   0.341187
# Adversarial Debias           0.108272   0.330792
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.628369       0.046355  1.105726       0.048438
# Reweighing                0.627451       0.003013  1.011226       0.005184
# Disparate Impact Remover  0.630303       0.066734  1.146401       0.068909
# Prejudice Remover         0.620790       0.012530  1.031031       0.014418
# Adversarial Debias        0.589824       0.046431  1.126117       0.047605
# Adversarial Debias        0.589710       0.079947  1.177796       0.080658
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.054793   0.244435
# Reweighing                   0.010134   0.254859
# Disparate Impact Remover     0.074495   0.231288
# Prejudice Remover            0.021412   0.255469
# Adversarial Debias           0.055878   0.313900
# Adversarial Debias           0.095170   0.263770
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.698149       0.033659  0.838760       0.063569
# Reweighing                0.699344       0.027404  0.987916       0.004322
# Disparate Impact Remover  0.698967       0.015052  0.816648       0.055440
# Prejudice Remover         0.689673       0.044511  1.017126       0.005075
# Adversarial Debias        0.538165       0.005682  0.892892       0.003187
# Adversarial Debias        0.527339       0.006068  1.015030       0.000230
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.005952   0.078847
# Reweighing                   0.057143   0.078707
# Disparate Impact Remover     0.025000   0.079396
# Prejudice Remover            0.083730   0.081172
# Adversarial Debias           0.014683   0.077678
# Adversarial Debias           0.011905   0.076449

# %%
def format_df(df):
    df = df.transpose()
    df.columns = ["None", "Reweighting", "DIR", "PR", "AD(Base)", "AD"]
    return df

heart_failure = format_df(heart_failure)
heart_failure

diabetes = format_df(diabetes)
post_acute = format_df(post_acute)

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.pairplot(heart_failure)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,3)
fig.suptitle('No Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,3)
fig.suptitle('Row Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')

r0 = np.arange(0.56, 0.74, step=0.02)
r1 = np.arange(0, 0.2, step=0.02)
r2 = np.arange(0.6, 1.3, step=0.1)
r3 = np.arange(0, 0.22, step=0.02)
r4 = np.arange(0, 0.22, step=0.02)
r5 = np.arange(0, 0.3, step=0.02)


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')
ax.set_yticks(r0)




df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')
ax.set_yticks(r1)


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')
ax.set_yticks(r3)



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')
ax.set_yticks(r4)


df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")
ax.set_yticks(r0)


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r1)



df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r2)



df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r3)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r4)



df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set_yticks(r5)



None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

# %%
plt.rcParams['figure.figsize'] = (10, 20)


fig, axs = plt.subplots(7,3)
fig.suptitle('All Normalization')
colors = ['b', 'c', 'y', 'm', 'r', 'g']
fig=plt.figure(figsize=(20,20), dpi= 600, facecolor='w', edgecolor='k')


#First Column

df_c1 = heart_failure
col = 0

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Heart Failure")
ax.set( ylabel= 'bal_acc')



df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'avg_odd_diff')


df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'disp_imp')


df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'stat_par_diff')



df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'eq_opp_diff')

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'theil_ind')


None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.set(ylabel= 'Legend')



#Second Column


df_c1 = diabetes
col = 1 

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Diabetes")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)





#Third Column


df_c1 = post_acute
col = 2

df_c = df_c1[0:1]
ax = axs[0,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)
ax.title.set_text("Post_Acute")


df_c = df_c1[1:2]
ax = axs[1,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[2:3]
ax = axs[2,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[3:4]
ax = axs[3,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


df_c = df_c1[4:5]
ax = axs[4,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

df_c = df_c1[5:6]
ax = axs[5,col]
None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
#ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)

None_ = ax.scatter(df_c["None"], df_c["None"], color=colors[0])
ax = axs[6,col]
Reweight = ax.scatter(df_c["None"], df_c["Reweighting"], color=colors[1])
DIR = ax.scatter(df_c["None"], df_c["DIR"], color=colors[2])
PR = ax.scatter(df_c["None"], df_c["PR"], color=colors[3])
ax.legend((None_,Reweight, DIR, PR),("None", "Reweighting", "DIR", "PR"),scatterpoints=1,loc='lower right',ncol=1,fontsize=8)


plt.setp(axs, yticks=(np.arange(0, 1, step=0.2)))
# Out:
# [<matplotlib.axis.YTick at 0x24fc532e6d0>,
#  <matplotlib.axis.YTick at 0x24fc532e280>,
#  <matplotlib.axis.YTick at 0x24fc532aa60>,
#  <matplotlib.axis.YTick at 0x24fc3ca3c40>,
#  <matplotlib.axis.YTick at 0x24fc2848f70>,
#  <matplotlib.axis.YTick at 0x24fc52daa00>,
#  <matplotlib.axis.YTick at 0x24fc52da580>,
#  <matplotlib.axis.YTick at 0x24fc52d1ca0>,
#  <matplotlib.axis.YTick at 0x24fc36d5370>,
#  <matplotlib.axis.YTick at 0x24fc3ca3580>,
#  <matplotlib.axis.YTick at 0x24fc5347bb0>,
#  <matplotlib.axis.YTick at 0x24fc5347790>,
#  <matplotlib.axis.YTick at 0x24fc5342ee0>,
#  <matplotlib.axis.YTick at 0x24fc36d5bb0>,
#  <matplotlib.axis.YTick at 0x24fc282bbb0>,
#  <matplotlib.axis.YTick at 0x24fc5373fd0>,
#  <matplotlib.axis.YTick at 0x24fc5373bb0>,
#  <matplotlib.axis.YTick at 0x24fc5373340>,
#  <matplotlib.axis.YTick at 0x24fbfa6ccd0>,
#  <matplotlib.axis.YTick at 0x24fbfad9a30>,
#  <matplotlib.axis.YTick at 0x24fc53a9430>,
#  <matplotlib.axis.YTick at 0x24fc53a1fd0>,
#  <matplotlib.axis.YTick at 0x24fc53a1760>,
#  <matplotlib.axis.YTick at 0x24fbfa6ce20>,
#  <matplotlib.axis.YTick at 0x24fc36d5c70>,
#  <matplotlib.axis.YTick at 0x24fc53d3880>,
#  <matplotlib.axis.YTick at 0x24fc53d3460>,
#  <matplotlib.axis.YTick at 0x24fc53ccbb0>,
#  <matplotlib.axis.YTick at 0x24fc5f289d0>,
#  <matplotlib.axis.YTick at 0x24fbfa45af0>,
#  <matplotlib.axis.YTick at 0x24fc53ffca0>,
#  <matplotlib.axis.YTick at 0x24fc53ff880>,
#  <matplotlib.axis.YTick at 0x24fc53f6fd0>,
#  <matplotlib.axis.YTick at 0x24fc36ddd00>,
#  <matplotlib.axis.YTick at 0x24fc36dd6d0>,
#  <matplotlib.axis.YTick at 0x24fc54330d0>,
#  <matplotlib.axis.YTick at 0x24fc542cc70>,
#  <matplotlib.axis.YTick at 0x24fc542c400>,
#  <matplotlib.axis.YTick at 0x24fc36dd940>,
#  <matplotlib.axis.YTick at 0x24fc5f28c10>,
#  <matplotlib.axis.YTick at 0x24fc54604f0>,
#  <matplotlib.axis.YTick at 0x24fc54600d0>,
#  <matplotlib.axis.YTick at 0x24fc5459820>,
#  <matplotlib.axis.YTick at 0x24fc1e815e0>,
#  <matplotlib.axis.YTick at 0x24fc1e81bb0>,
#  <matplotlib.axis.YTick at 0x24fc548c910>,
#  <matplotlib.axis.YTick at 0x24fc548c4f0>,
#  <matplotlib.axis.YTick at 0x24fc5484c40>,
#  <matplotlib.axis.YTick at 0x24fc1460bb0>,
#  <matplotlib.axis.YTick at 0x24fc188f3d0>,
#  <matplotlib.axis.YTick at 0x24fc54bbd30>,
#  <matplotlib.axis.YTick at 0x24fc54bb910>,
#  <matplotlib.axis.YTick at 0x24fc54b1e50>,
#  <matplotlib.axis.YTick at 0x24fbfc0be50>,
#  <matplotlib.axis.YTick at 0x24fc1e81700>,
#  <matplotlib.axis.YTick at 0x24fc54f2190>,
#  <matplotlib.axis.YTick at 0x24fc54ebd30>,
#  <matplotlib.axis.YTick at 0x24fc54eb4c0>,
#  <matplotlib.axis.YTick at 0x24fc281b6a0>,
#  <matplotlib.axis.YTick at 0x24fbfbd9ca0>,
#  <matplotlib.axis.YTick at 0x24fc55235b0>,
#  <matplotlib.axis.YTick at 0x24fc5523190>,
#  <matplotlib.axis.YTick at 0x24fc551b8e0>,
#  <matplotlib.axis.YTick at 0x24fc17ca8b0>,
#  <matplotlib.axis.YTick at 0x24fc149e3a0>,
#  <matplotlib.axis.YTick at 0x24fc55529d0>,
#  <matplotlib.axis.YTick at 0x24fc55525b0>,
#  <matplotlib.axis.YTick at 0x24fc5548d00>,
#  <matplotlib.axis.YTick at 0x24fc149e580>,
#  <matplotlib.axis.YTick at 0x24fbfbd9bb0>,
#  <matplotlib.axis.YTick at 0x24fc5582df0>,
#  <matplotlib.axis.YTick at 0x24fc55829d0>,
#  <matplotlib.axis.YTick at 0x24fc5582100>,
#  <matplotlib.axis.YTick at 0x24fc15942e0>,
#  <matplotlib.axis.YTick at 0x24fc15947c0>,
#  <matplotlib.axis.YTick at 0x24fc2b331f0>,
#  <matplotlib.axis.YTick at 0x24fc2b33c70>,
#  <matplotlib.axis.YTick at 0x24fc3e30430>,
#  <matplotlib.axis.YTick at 0x24fc1536340>,
#  <matplotlib.axis.YTick at 0x24fc318a190>,
#  <matplotlib.axis.YTick at 0x24fc5fa6700>,
#  <matplotlib.axis.YTick at 0x24fc5fa6520>,
#  <matplotlib.axis.YTick at 0x24fc35802b0>,
#  <matplotlib.axis.YTick at 0x24fc1536880>,
#  <matplotlib.axis.YTick at 0x24fbf8e6070>,
#  <matplotlib.axis.YTick at 0x24fc3b8ca30>,
#  <matplotlib.axis.YTick at 0x24fc3b8c6a0>,
#  <matplotlib.axis.YTick at 0x24fc2c5baf0>,
#  <matplotlib.axis.YTick at 0x24fc318ae80>,
#  <matplotlib.axis.YTick at 0x24fc3700d90>,
#  <matplotlib.axis.YTick at 0x24fc2c8d130>,
#  <matplotlib.axis.YTick at 0x24fc2c8d520>,
#  <matplotlib.axis.YTick at 0x24fc3c6ec40>,
#  <matplotlib.axis.YTick at 0x24fc37001f0>,
#  <matplotlib.axis.YTick at 0x24fc2dc0df0>,
#  <matplotlib.axis.YTick at 0x24fc5b34190>,
#  <matplotlib.axis.YTick at 0x24fc5b34eb0>,
#  <matplotlib.axis.YTick at 0x24fc2c5aee0>,
#  <matplotlib.axis.YTick at 0x24fc3700190>,
#  <matplotlib.axis.YTick at 0x24fc318aca0>,
#  <matplotlib.axis.YTick at 0x24fc1ebb790>,
#  <matplotlib.axis.YTick at 0x24fc1ebb2e0>,
#  <matplotlib.axis.YTick at 0x24fc2ba1310>,
#  <matplotlib.axis.YTick at 0x24fc35917c0>,
#  <matplotlib.axis.YTick at 0x24fc3591340>]

# %%
plt.show()

# %%
plt.rcParams['figure.figsize'] = [12, 5]
display(heart_failure)

#heart_failure.index = heart_failure.index.droplevel(1)
heart_failure.plot()
# Out:
#                    None  Reweighting       DIR        PR  AD(Base)        AD
# bal_acc        0.582911     0.588429  0.595697  0.573653  0.560098  0.561663
# avg_odds_diff  0.084798     0.031474  0.167005  0.026369  0.057676  0.081967
# disp_imp       0.793933     0.916726  0.702656  1.042650  0.809662  0.739828
# stat_par_diff  0.090230     0.035478  0.168906  0.028265  0.048429  0.076974
# eq_opp_diff    0.072426     0.025368  0.169853  0.010846  0.100551  0.108272
# theil_ind      0.263803     0.252357  0.221920  0.147566  0.341187  0.330792
# <AxesSubplot:>

# %%
display(diabetes)

#diabetes.index = diabetes.index.droplevel(1)

diabetes.plot()
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.628369       0.046355  1.105726       0.048438
# Reweighing                0.627451       0.003013  1.011226       0.005184
# Disparate Impact Remover  0.630303       0.066734  1.146401       0.068909
# Prejudice Remover         0.620790       0.012530  1.031031       0.014418
# Adversarial Debias        0.589824       0.046431  1.126117       0.047605
# Adversarial Debias        0.589710       0.079947  1.177796       0.080658
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.054793   0.244435
# Reweighing                   0.010134   0.254859
# Disparate Impact Remover     0.074495   0.231288
# Prejudice Remover            0.021412   0.255469
# Adversarial Debias           0.055878   0.313900
# Adversarial Debias           0.095170   0.263770
# <AxesSubplot:xlabel='Bias Mitigator'>

# %%
display(post_acute)

#post_acute.index = post_acute.index.droplevel(1)
post_acute.plot()
# Out:
#                            bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Bias Mitigator
# None                      0.698149       0.033659  0.838760       0.063569
# Reweighing                0.699344       0.027404  0.987916       0.004322
# Disparate Impact Remover  0.698967       0.015052  0.816648       0.055440
# Prejudice Remover         0.689673       0.044511  1.017126       0.005075
# Adversarial Debias        0.538165       0.005682  0.892892       0.003187
# Adversarial Debias        0.527339       0.006068  1.015030       0.000230
#
#                           eq_opp_diff  theil_ind
# Bias Mitigator
# None                         0.005952   0.078847
# Reweighing                   0.057143   0.078707
# Disparate Impact Remover     0.025000   0.079396
# Prejudice Remover            0.083730   0.081172
# Adversarial Debias           0.014683   0.077678
# Adversarial Debias           0.011905   0.076449
# <AxesSubplot:xlabel='Bias Mitigator'>
